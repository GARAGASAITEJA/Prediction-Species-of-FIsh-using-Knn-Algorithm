# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'C:\Users\VAIO\Desktop\PYQT5\ml1\LogisticRegression\Fish Weight estimation\Fishspecies.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(556, 493)
        Form.setStyleSheet("font: 16pt \"MS Shell Dlg 2\";\n"
"color:rgb(255, 85, 0)")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(36, 60, 91, 21))
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(36, 100, 91, 21))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(36, 140, 91, 20))
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(280, 50, 81, 31))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(280, 90, 71, 21))
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(280, 130, 81, 16))
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(210, 290, 151, 91))
        self.label_7.setObjectName("label_7")
        self.pushButton = QtWidgets.QPushButton(Form)
        self.pushButton.setGeometry(QtCore.QRect(190, 230, 161, 31))
        self.pushButton.setObjectName("pushButton")
        self.lineEdit = QtWidgets.QLineEdit(Form)
        self.lineEdit.setGeometry(QtCore.QRect(140, 60, 113, 20))
        self.lineEdit.setObjectName("lineEdit")
        self.lineEdit_2 = QtWidgets.QLineEdit(Form)
        self.lineEdit_2.setGeometry(QtCore.QRect(140, 100, 113, 20))
        self.lineEdit_2.setObjectName("lineEdit_2")
        self.lineEdit_3 = QtWidgets.QLineEdit(Form)
        self.lineEdit_3.setGeometry(QtCore.QRect(140, 140, 113, 20))
        self.lineEdit_3.setObjectName("lineEdit_3")
        self.lineEdit_4 = QtWidgets.QLineEdit(Form)
        self.lineEdit_4.setGeometry(QtCore.QRect(380, 50, 113, 20))
        self.lineEdit_4.setObjectName("lineEdit_4")
        self.lineEdit_5 = QtWidgets.QLineEdit(Form)
        self.lineEdit_5.setGeometry(QtCore.QRect(380, 90, 113, 20))
        self.lineEdit_5.setObjectName("lineEdit_5")
        self.lineEdit_6 = QtWidgets.QLineEdit(Form)
        self.lineEdit_6.setGeometry(QtCore.QRect(380, 130, 113, 20))
        self.lineEdit_6.setObjectName("lineEdit_6")

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
        self.pushButton.clicked.connect(self.predictfishspecies)


    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", " Weight:"))
        self.label_2.setText(_translate("Form", "Length1:"))
        self.label_3.setText(_translate("Form", "Length2:"))
        self.label_4.setText(_translate("Form", "Length3:"))
        self.label_5.setText(_translate("Form", "Height:"))
        self.label_6.setText(_translate("Form", "Width:"))
        self.label_7.setText(_translate("Form", "Species Type"))
        self.pushButton.setText(_translate("Form", "PushButton")) 
        
    def predictfishspecies(self):
        import pandas as pd
        import matplotlib.pyplot as plt
        from sklearn.model_selection import train_test_split 
        from sklearn.linear_model import LogisticRegression

        path = "C:\\Users\\VAIO\\Desktop\\PYQT5\\ml1\\LogisticRegression\\Fish Weight estimation\\Fish.csv"

        data = pd.read_csv(path)
        print(data)

        inputs = data.drop('Species','columns')
        output = data.drop(['Weight','Length1','Length2','Length3','Height','Width'],'columns')
        print(inputs)
        print(output)
        ###
        x_train,x_test,y_train,y_test=train_test_split(inputs,output,train_size=0.8)
        print(x_train)
        print(x_test)
        print(y_train)
        print(y_test)
        model=LogisticRegression()#Intialising the model
        model.fit(inputs,output)
        y_predic=model.predict(x_test)
        print(y_predic)#predicted value from trained model
        print(y_test)# actual data from dataset
        from sklearn.metrics import confusion_matrix
        cm=confusion_matrix(y_test,y_predic)
        print(cm)
        strWeight=float(self.lineEdit.text())
        strLength1=float(self.lineEdit_2.text())
        strLength2=float(self.lineEdit_3.text())
        strLength3=float(self.lineEdit_4.text())
        strHeight=float(self.lineEdit_5.text())
        strWidth=float(self.lineEdit_6.text()) 
        strresult=model.predict([[strWeight,strLength1,strLength2,strLength3,strHeight,strWidth]])
        self.label_7.setText((str(strresult)))

if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
